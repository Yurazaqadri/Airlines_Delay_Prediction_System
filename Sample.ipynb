# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
df=pd.read_csv('2006.csv')

# %%
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 0        2006      1          11          3    743.0         745   1024.0  \
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...

# %%
df['ActualElapsedTime'] = df['ActualElapsedTime'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['CRSElapsedTime'] = df['CRSElapsedTime'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['AirTime'] = df['AirTime'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['ArrTime'] = df['ArrTime'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['ArrDelay'] = df['ArrDelay'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['CarrierDelay'] = df['CarrierDelay'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['WeatherDelay'] = df['WeatherDelay'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['NASDelay'] = df['NASDelay'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['LateAircraftDelay'] = df['LateAircraftDelay'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['SecurityDelay'] = df['SecurityDelay'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['TaxiIn'] = df['TaxiIn'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df['TaxiOut'] = df['TaxiOut'].interpolate(method='linear', limit_direction='both', axis=0) #Interpolation
df.isna().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# DepTime               121934
# CRSDepTime                 0
# ArrTime                    0
# CRSArrTime                 0
# UniqueCarrier              0
# FlightNum                  0
# TailNum                    0
# ActualElapsedTime          0
# CRSElapsedTime             0
# AirTime                    0
# ArrDelay                   0
# DepDelay              121934
# Origin                     0
# Dest                       0
# Distance                   0
# TaxiIn                     0
# TaxiOut                    0
# Cancelled                  0
# CancellationCode     7019988
# Diverted                   0
# CarrierDelay               0
# WeatherDelay               0
# NASDelay                   0
# SecurityDelay              0
# LateAircraftDelay          0
# dtype: int64

# %%
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 0        2006      1          11          3    743.0         745   1024.0  \
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...

# %%
df.isna().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# DepTime               121934
# CRSDepTime                 0
# ArrTime                    0
# CRSArrTime                 0
# UniqueCarrier              0
# FlightNum                  0
# TailNum                    0
# ActualElapsedTime          0
# CRSElapsedTime             0
# AirTime                    0
# ArrDelay                   0
# DepDelay              121934
# Origin                     0
# Dest                       0
# Distance                   0
# TaxiIn                     0
# TaxiOut                    0
# Cancelled                  0
# CancellationCode     7019988
# Diverted                   0
# CarrierDelay               0
# WeatherDelay               0
# NASDelay                   0
# SecurityDelay              0
# LateAircraftDelay          0
# dtype: int64

# %%
df = df.dropna(subset=['DepTime', 'TailNum'])
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime
# 0        2006      1          11          3    743.0         745   1024.0  \
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled
# ...

# %%
# Converting Categorical Variables to object type
df.loc[:, 'Year'] = df['Year'].astype(object)
df.loc[:, 'Month'] = df['Month'].astype(object)
df.loc[:, 'DayofMonth'] = df['DayofMonth'].astype(object)
df.loc[:, 'DayOfWeek'] = df['DayOfWeek'].astype(object)

df.loc[:, 'UniqueCarrier'] = df['UniqueCarrier'].astype(object)
df.loc[:, 'FlightNum'] = df['FlightNum'].astype(object)
df.loc[:, 'TailNum'] = df['TailNum'].astype(object)

df.loc[:, 'Origin'] = df['Origin'].astype(object)
df.loc[:, 'Dest'] = df['Dest'].astype(object)

df.loc[:, 'Cancelled'] = df['Cancelled'].astype(object)
df.loc[:, 'CancellationCode'] = df['CancellationCode'].astype(object)
df.loc[:, 'Diverted'] = df['Diverted'].astype(object)

# %%
df.dtypes
# Out:
# Year                  object
# Month                 object
# DayofMonth            object
# DayOfWeek             object
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum             object
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn                 int64
# TaxiOut                int64
# Cancelled             object
# CancellationCode      object
# Diverted              object
# CarrierDelay           int64
# WeatherDelay           int64
# NASDelay               int64
# SecurityDelay          int64
# LateAircraftDelay      int64
# dtype: object

# %%
df.isna().any()
# Out:
# Year                 False
# Month                False
# DayofMonth           False
# DayOfWeek            False
# DepTime              False
# CRSDepTime           False
# ArrTime              False
# CRSArrTime           False
# UniqueCarrier        False
# FlightNum            False
# TailNum              False
# ActualElapsedTime    False
# CRSElapsedTime       False
# AirTime              False
# ArrDelay             False
# DepDelay             False
# Origin               False
# Dest                 False
# Distance             False
# TaxiIn               False
# TaxiOut              False
# Cancelled            False
# CancellationCode      True
# Diverted             False
# CarrierDelay         False
# WeatherDelay         False
# NASDelay             False
# SecurityDelay        False
# LateAircraftDelay    False
# dtype: bool

# %%
df = df.loc[:, df.columns != 'CancellationCode']

# %%
df.shape
# Out:
# (7019988, 28)

# %%
df['Delay'] = ''

# %%
df['Delay'] = np.where((df['ArrDelay'] <= 0) & (df['DepDelay'] <= 0), 'N', 'Y')

# %%
df
# Out:
#          Year Month DayofMonth DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008     1          3         4   1343.0        1325   1451.0
# 1        2008     1          3         4   1125.0        1120   1247.0
# 2        2008     1          3         4   2009.0        2015   2136.0
# 3        2008     1          3         4    903.0         855   1203.0
# 4        2008     1          3         4   1423.0        1400   1726.0
# ...       ...   ...        ...       ...      ...         ...      ...
# 2389212  2008     4         17         4   1025.0        1025   1234.0
# 2389213  2008     4         17         4   1319.0        1320   1527.0
# 2389214  2008     4         17         4   1335.0        1335   1556.0
# 2389215  2008     4         17         4   1933.0        1935   2140.0
# 2389216  2008     4         17         4    621.0         615    752.0
#
#          CRSArrTime UniqueCarrier FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
(df.isna().sum())*100
# Out:
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# Delay                0
# dtype: int64

# %%
# drop rows with null values
df_clean = df.dropna()

# sample 4000 rows from the cleaned dataframe
df1 = df_clean.sample(n=1000, random_state=42)

# %%
# save the DataFrame to a CSV file
df1.to_csv("2006sample.csv", index=False)
